# %%
import pickle
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
import glob

# %%
df = pickle.load(open('df.p', 'rb'))

df
# Out:
#                                                    url          created_at  \
# 0    https://api.github.com/repos/duckduckgo/privac... 2022-07-30 06:17:39
# 1    https://api.github.com/repos/WaterfoxCo/Waterf... 2017-09-02 13:52:15
# 2    https://api.github.com/repos/resonatecoop/stre... 2021-08-03 13:44:21
# 3    https://api.github.com/repos/brave/browser-lap... 2017-08-10 05:51:12
# 4    https://api.github.com/repos/duckduckgo/Androi... 2022-12-19 10:17:16
# ..                                                 ...                 ...
# 466  https://api.github.com/repos/EFForg/action-cen... 2017-09-11 21:18:11
# 467  https://api.github.com/repos/ualbertalib/jupit... 2018-02-21 14:55:50
# 471  https://api.github.com/repos/department-of-vet... 2017-03-28 17:22:44
# 474  https://api.github.com/repos/cfpb/consumerfina... 2017-02-07 19:51:45
# 475  https://api.github.com/repos/GeoNode/geonode/i... 2017-05-10 16:55:58
#
#                                                  title  \
# ...

# %%
df.iloc[0].issue['repository_url']
# Out:
# 'https://api.github.com/repos/duckduckgo/privacy-configuration'

# %%
df
# Out:
#                                                    url          created_at  \
# 0    https://api.github.com/repos/duckduckgo/privac... 2022-07-30 06:17:39
# 1    https://api.github.com/repos/WaterfoxCo/Waterf... 2017-09-02 13:52:15
# 2    https://api.github.com/repos/resonatecoop/stre... 2021-08-03 13:44:21
# 3    https://api.github.com/repos/brave/browser-lap... 2017-08-10 05:51:12
# 4    https://api.github.com/repos/duckduckgo/Androi... 2022-12-19 10:17:16
# ..                                                 ...                 ...
# 466  https://api.github.com/repos/EFForg/action-cen... 2017-09-11 21:18:11
# 467  https://api.github.com/repos/ualbertalib/jupit... 2018-02-21 14:55:50
# 471  https://api.github.com/repos/department-of-vet... 2017-03-28 17:22:44
# 474  https://api.github.com/repos/cfpb/consumerfina... 2017-02-07 19:51:45
# 475  https://api.github.com/repos/GeoNode/geonode/i... 2017-05-10 16:55:58
#
#                                                  title  \
# ...

# %%
number_issues = len(df['url'])

df['project'] = df[['issue']]['issue'].transform(lambda x: x['repository_url'])
df = df.copy()
number_projects = len(df[['project']].groupby(['project']))

f'#of issues {number_issues}, #of projects {number_projects}'
# Out:
# '#of issues 21608, #of projects 5892'

# %%
df[['project']].value_counts()
# Out:
# project
# https://api.github.com/repos/vz-risk/VCDB                                         2173
# https://api.github.com/repos/AdguardTeam/AdguardFilters                           1667
# https://api.github.com/repos/brave/browser-laptop                                  371
# https://api.github.com/repos/ministryofjustice/hmpps-book-secure-move-frontend     287
# https://api.github.com/repos/mozilla-mobile/fenix                                  170
#                                                                                   ...
# https://api.github.com/repos/dockstore/dockstore                                     1
# https://api.github.com/repos/doctrine/dbal                                           1
# https://api.github.com/repos/dof-dss/Unity_svr_2                                     1
# https://api.github.com/repos/dogecoinfoundation/dogecoin.com                         1
# https://api.github.com/repos/zxing-cpp/zxing-cpp                                     1
# ...

# %%
# %matplotlib inline

plt.hist(df[['project']].value_counts(), 100)
plt.show()

# %%
import pickle
data = pickle.load(open('../projects.p', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pickle
# ----> 2 data = pickle.load(open('../projects.p'))
#
# File /usr/lib/python3.10/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
